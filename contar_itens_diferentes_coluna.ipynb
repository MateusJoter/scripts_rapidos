# %%
import pandas as pd

# %%
path = r"C:\Users\mateu\OneDrive\Desktop\scripts rapidos\vias fortaleza.xlsx"
df = pd.read_excel(path)

# %%
print(df.columns)
# Out:
# Index(['full_id', 'osm_id', 'osm_type', 'highway', 'maxspeed'], dtype='object')

# %%
print(df['highway'].value_counts().reset_index())
# Out:
#            highway  count
# 0      residential  18468
# 1          footway  16173
# 2          service  11474
# 3          primary   2629
# 4         tertiary   1724
# 5    living_street    967
# 6        secondary    891
# 7         cycleway    617
# 8             path    551
# 9     primary_link    425
# 10           trunk    299
# 11    unclassified    205
# 12      trunk_link    172
# 13           steps    169
# 14      pedestrian    163
# 15   tertiary_link    139
# 16           track     81
# 17  secondary_link     71
# 18          busway     66
# 19    construction     60
# 20         raceway     15
# 21        proposed      7
# 22        corridor      7
# 23        elevator      5
# 24        services      4
# 25           dummy      1

# %%
highway_dict = df['highway'].value_counts().reset_index()

# %%
for chave, valor in zip(highway_dict['highway'], highway_dict['count']):
    print(chave, valor)
# Out:
# residential 18468
# footway 16173
# service 11474
# primary 2629
# tertiary 1724
# living_street 967
# secondary 891
# cycleway 617
# path 551
# primary_link 425
# trunk 299
# unclassified 205
# trunk_link 172
# steps 169
# pedestrian 163
# tertiary_link 139
# track 81
# secondary_link 71
# busway 66
# construction 60
# raceway 15
# proposed 7
# corridor 7
# elevator 5
# services 4
# dummy 1
